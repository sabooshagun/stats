# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/shagunsaboo/Downloads/startup.csv')
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df['CityLocation'].replace({"Delhi":"New Delhi","bangalore":"Bangalore"})
# Out:
# 0       Bangalore
# 1          Mumbai
# 2       New Delhi
# 3          Mumbai
# 4       Hyderabad
# 5       Bangalore
# 6       Ahmedabad
# 7         Gurgaon
# 8       Bangalore
# 9           Noida
# 10         Mumbai
# 11      Bangalore
# 12        Gurgaon
# 13      Bangalore
# 14      Bangalore
# 15      Hyderabad
# 16           Pune
# 17         Mumbai
# 18      Bangalore
# 19      Bangalore
# 20      Hyderabad
# 21      Bangalore
# 22           Pune
# 23      Bangalore
# 24      Bangalore
# 25      Bangalore
# 26           Pune
# 27          Noida
# 28      Hyderabad
# 29        Kolkata
#           ...
# 2342          NaN
# 2343          NaN
# 2344          NaN
# 2345          NaN
# 2346          NaN
# 2347          NaN
# 2348          NaN
# 2349          NaN
# 2350          NaN
# 2351          NaN
# 2352          NaN
# 2353          NaN
# 2354          NaN
# 2355          NaN
# 2356          NaN
# 2357          NaN
# 2358          NaN
# 2359          NaN
# 2360          NaN
# ...

# %%
location_val = (df.loc[(df["CityLocation"]=="New Delhi") | (df["CityLocation"]=="Banglore") | (df["CityLocation"]=="Gurgaon") | (df["CityLocation"]=="Noida") | (df["CityLocation"]=="Mumbai") | (df["CityLocation"]=="Pune")] )

# %%
location_val
# Out:
#        SNo        Date           StartupName  \
# 1        1  02/08/2017               Ethinos
# 2        2  02/08/2017          Leverage Edu
# 3        3  02/08/2017                  Zepo
# 7        7  04/07/2017                 Droom
# 9        9  05/07/2017                Moglix
# 10      10  05/07/2017            Timesaverz
# 12      12  06/07/2017           MyCity4kids
# 16      16  11/07/2017                Fabogo
# 17      17  11/07/2017            Flickstree
# 22      22  12/07/2017              Arcatron
# 26      26  17/07/2017                Vayana
# 27      27  18/07/2017             MObiquest
# 34      34  20/07/2017                Trupay
# 35      35  21/07/2017            Brick2Wall
# 36      36  21/07/2017           FableStreet
# 37      37  21/07/2017       Monsoon Fintech
# 41      41  26/07/2017     Creator’s Gurukul
# 42      42  26/07/2017            Fab Hotels
# 44      44  27/07/2017                   1mg
# 45      45  28/07/2017               Jhakaas
# ...

# %%
amount=df['AmountInUSD']
amount.head()
amount.dropna(inplace=True)
a1=amount.str.replace(',', '')
a1.head()
a2=pd.to_numeric(a1)
a2
# Out:
# 0         1300000
# 3          500000
# 4          850000
# 5         1000000
# 6         2600000
# 7        20000000
# 8         8500000
# 9        12000000
# 10        1000000
# 13        1000000
# 15        3000000
# 16        2250000
# 17         464000
# 19       18500000
# 23         540000
# 24        1700000
# 25        2000000
# 26        4000000
# 31       10000000
# 33         600000
# 34         700000
# 35         200000
# 39        1200000
# 40       35000000
# 42       25000000
# 43         200000
# 44       15000000
# 46        1250000
# 50       50000000
# 52        1000000
#           ...
# 2331      5000000
# 2333     13000000
# 2336       290000
# 2338     50000000
# 2339       650000
# 2340       161000
# 2341    100000000
# 2342       330000
# 2344       200000
# 2345        16000
# 2346        16000
# 2347        16000
# 2348        16000
# 2349        16000
# 2350     11000000
# 2352       200000
# 2353     14750000
# 2354       325000
# 2356      3250000
# ...

# %%
pop_max=a2.max()
print(pop_max)
# Out:
# 1400000000

# %%
location_delhi = (df.loc[(df["CityLocation"]=="New Delhi") | (df["CityLocation"]=="Gurgaon") | (df["CityLocation"]=="Noida")].sample(n=20))
location_delhi
# Out:
#        SNo        Date     StartupName                IndustryVertical  \
# 1022  1022   11/5/2016        Faircent               Consumer Internet
# 165    165  23/05/2017        Magicpin               Consumer Internet
# 199    199  07/04/2017           QorQI                      Healthcare
# 1321  1321  24/02/2016        Pocketin               Consumer Internet
# 1272  1272  10/02/2016           OyBob                       eCommerce
# 1858  1858  17/08/2015       ShadowFax      on-demand delivery service
# 2189  2189  27/04/2015           GIBBS                      Clean Tech
# 931    931  14/06/2016          Gobolt                       Logistics
# 249    249  28/04/2017        Sepalika               Consumer Internet
# 1458  1458  07/12/2015  Leaf Wearables   Smart Safety Wearable Devices
# 36      36  21/07/2017     FableStreet                       eCommerce
# 299    299  23/03/2017           Ixigo               Consumer Internet
# ...

# %%
location_bangalore = (df.loc[(df["CityLocation"]=="Bangalore")].sample(n=20))
location_bangalore
# Out:
#        SNo        Date    StartupName  \
# 723    723   23/9/2016     Parentlane
# 783    783  17/08/2016         Pikkol
# 995    995   03/5/2016         Zwayam
# 2138  2138  03/04/2015         Swiggy
# 572    572  28/11/2016        Kloseby
# 186    186  03/04/2017      SmartCoin
# 1401  1401  21/01/2016         Fisdom
# 319    319  31/03/2017      BigBasket
# 1318  1318  24/02/2016        LoanZen
# 1169  1169   07/3/2016         Wooplr
# 1144  1144  28/04/2016        DocsApp
# 2034  2034  15/06/2015          iSTAR
# 1977  1977   28/7/2015         Opinio
# 706    706   19/9/2016         Milofy
# 88      88  20/06/2017    ForeverShop
# 2049  2049  20/06/2015         Cupick
# 1581  1581  19/11/2015  PlaceofOrigin
# 708    708   19/9/2016         Swiggy
# 1616  1616  30/11/2015          Bro4U
# 1972  1972   27/7/2015       Townrush
#
#                               IndustryVertical  \
# 723                          Consumer Internet
# 783                                  Logistics
# ...

# %%
location_pune = (df.loc[(df["CityLocation"]=="Pune")].sample(n=20))
location_pune
# Out:
#        SNo        Date        StartupName  \
# 357    357  17/02/2017         TownScript
# 371    371  02/01/2017           TaxSutra
# 271    271  07/03/2017           Agrostar
# 933    933  14/06/2016              Sminq
# 1629  1629  06/10/2015          DocPlexus
# 1848  1848  13/08/2015           Agrostar
# 1003  1003   04/5/2016           Comarete
# 1346  1346  06/01/2016  PlanMyMedicalTrip
# 1808  1808  05/08/2015               Grex
# 481    481  15/12/2016             SERV’D
# 867    867  14/07/2016         ShoppinPal
# 1947  1947   15/7/2015            Mobikon
# 1992  1992   31/7/2015            Prothom
# 1159  1159   04/3/2016  Arcatron Mobility
# 582    582  30/11/2016       Interviewpad
# 737    737   30/9/2016             Demyto
# 539    539  14/11/2016         ElasticRun
# 428    428  25/01/2017         RML Agtech
# 1133  1133  25/04/2016         intouchapp
# 413    413  20/01/2017             Ethosh
#
#                                        IndustryVertical  \
# ...

# %%
location_mumbai = (df.loc[(df["CityLocation"]=="Mumbai")].sample(n=20))
location_mumbai
# Out:
#        SNo        Date    StartupName                 IndustryVertical  \
# 2179  2179  23/04/2015   Craftstvilla         Ethnic Product eCommerce
# 94      94  21/06/2017      OneAssist                Consumer Internet
# 847    847  07/07/2016      SpectraVR                       Technology
# 714    714   21/9/2016      Pepperfry                        eCommerce
# 230    230  20/04/2017       HolaChef                Consumer Internet
# 1553  1553  09/11/2015      Skoov.com  eCommerce Product Search Engine
# 305    305  28/03/2017           Fynd                        ECommerce
# 99      99  23/06/2017         Voxweb                Consumer Internet
# 346    346  14/02/2017       CCAvenue                Consumer Internet
# 1907  1907  03/07/2015          Goqii       Mobile Fitness Marketplace
# 1996  1996  01/06/2015        Truebil             Used Car Marketplace
# 959    959  21/06/2016  PrettySecrets                        eCommerce
# ...

# %%
location_hyderabad = (df.loc[(df["CityLocation"]=="Hyderabad")].sample(n=20))
location_hyderabad
# Out:
#        SNo        Date            StartupName  \
# 766    766  11/08/2016                 Zenoti
# 907    907  08/06/2016            Grey Campus
# 732    732   28/9/2016             Celes Care
# 2192  2192  28/04/2015            Jay Robotix
# 15      15  10/07/2017             Autorox.co
# 1782  1782  24/09/2015  Fourth Partner Energy
# 1739  1739  12/09/2015             YatraGenie
# 1215  1215   23/3/2016       Endless Robotics
# 597    597  04/10/2016                NetLinx
# 1004  1004   04/5/2016        MyDentistChoice
# 1940  1940   14/7/2015           MySmartPrice
# 28      28  18/07/2017                  Ambee
# 2142  2142  07/04/2015            Pricejugaad
# 1012  1012   07/5/2016               Zebroads
# 62      62  08/06/2017   Multiplier Solutions
# 1320  1320  24/02/2016             AppilyEver
# 485    485  16/12/2016        Pi Data Centers
# 1971  1971   27/7/2015            ManageMySpa
# 710    710   20/9/2016            JustLikeNew
# ...

# %%
sample_df=pd.concat([location_bangalore,location_delhi,location_mumbai,location_pune,location_hyderabad])
sample_df
# Out:
#        SNo        Date              StartupName  \
# 1366  1366  12/01/2016            iBus Networks
# 1904  1904  02/07/2015                  Gozoomo
# 952    952  21/06/2016                  REstate
# 354    354  17/02/2017                  The Ken
# 1972  1972   27/7/2015                 Townrush
# 1783  1783  24/09/2015                  Licious
# 562    562  23/11/2016                    Udaan
# 1429  1429  29/01/2016                FreshMenu
# 1563  1563  16/11/2015                 Absentia
# 1107  1107  15/04/2016                 Tapchief
# 1210  1210   22/3/2016                 DrivoJoy
# 1176  1176   08/3/2016                    dunzo
# 1549  1549  09/11/2015  iStar Skill Development
# 1815  1815  06/08/2015                   Klozee
# 227    227  18/04/2017                   Whodat
# 97      97  22/06/2017   Explore Life traveling
# 134    134  09/05/2017           Uncanny Vision
# 1977  1977   28/7/2015                   Opinio
# ...

# %%
sample_max=sample_df.max()
print(sample_max)
# Out:
# SNo                                               2192
# Date                                         31/8/2016
# StartupName                                    mishTag
# IndustryVertical    fund raising platform for startups
# CityLocation                                      Pune
# InvestmentType                            Seed Funding
# dtype: object
