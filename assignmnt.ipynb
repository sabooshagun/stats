# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/shagunsaboo/Downloads/startup.csv')
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
delhi_val = (df.loc[(df["CityLocation"]=="New Delhi") | (df["CityLocation"]=="Banglore") | (df["CityLocation"]=="banglore") | (df["CityLocation"]=="delhi")] )

# %%
delhi_val
# Out:
#        SNo        Date              StartupName  \
# 2        2  02/08/2017             Leverage Edu
# 36      36  21/07/2017              FableStreet
# 37      37  21/07/2017          Monsoon Fintech
# 41      41  26/07/2017        Creator’s Gurukul
# 42      42  26/07/2017               Fab Hotels
# 56      56  06/06/2017               wayForward
# 57      57  06/06/2017                 GyanDhan
# 59      59  07/06/2017                  ZipLoan
# 70      70  12/06/2017               PeeSafe.in
# 73      73  13/06/2017               HyperTrack
# 85      85  16/06/2017              HealthIntel
# 103    103  27/06/2017                 Stashfin
# 106    106  28/06/2017                   FiTraQ
# 109    109  29/06/2017                  Fitpass
# 121    121  04/05/2017               Healthians
# 122    122  05/05/2017                HealthMir
# 128    128  08/05/2017                Nightstay
# 130    130  08/05/2017                 MyGreens
# ...

# %%
amount_city=delhi_val['AmountInUSD']
amount_city.head()
# Out:
# 2            NaN
# 36           NaN
# 37           NaN
# 41           NaN
# 42    25,000,000
# Name: AmountInUSD, dtype: object

# %%
amount_city.dropna(inplace=True)
amount_city.head()

a1=amount_city.str.replace(',','')
a1.head()
# Out:
# /Users/shagunsaboo/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(result)
# 42     25000000
# 56      1000000
# 59       650000
# 70      1000000
# 103     5000000
# Name: AmountInUSD, dtype: object

# %%
a2=pd.to_numeric(a1)
a2
# Out:
# 42       25000000
# 56        1000000
# 59         650000
# 70        1000000
# 103       5000000
# 109       1000000
# 130       1000000
# 133         50000
# 145       5000000
# 162      30000000
# 192        500000
# 209       4000000
# 223        620000
# 226       2000000
# 229        155000
# 243       1000000
# 249        750000
# 274         30000
# 282        443000
# 291       3100000
# 303     100000000
# 343        330000
# 363       1100000
# 369       1000000
# 402        441000
# 407        650000
# 417         50000
# 420      15000000
# 437         22500
# 441       2000000
#           ...
# 1916      5000000
# 1928     10200000
# 1934       600000
# 1938     10000000
# 1953     15000000
# 1956      1000000
# 1980      2400000
# 1985     16000000
# 1995      6000000
# 1997      4000000
# 1998       350000
# 2008       100000
# 2010       150000
# 2014    137000000
# 2023      5000000
# 2057      1600000
# 2059      1000000
# 2067      8600000
# 2071     10000000
# ...

# %%
pop_avg=a2.mean()
pop_min=a2.min()
pop_max=a2.max()
print(pop_avg)
print(pop_min)
print(pop_max)
# Out:
# 12972865.566037735
# 22500
# 680000000

# %%
population=a2
sample_size=75
sample=population.sample(sample_size,random_state = 1)
sample.shape
# Out:
# (75,)

# %%
sample_avg=sample.mean()
sample_min=sample.min()
sample_max=sample.max()
print(pop_avg," ",sample_avg)
print(pop_min," ",sample_min)
print(pop_max," ",sample_max)
# Out:
# 12972865.566037735   22085206.666666668
# 22500   22500
# 680000000   680000000

# %%
sampling_error=pop_avg-sample_avg
print(sampling_error)
# Out:
# -9112341.100628933
